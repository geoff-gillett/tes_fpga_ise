# %%
from tes.data import Data
import numpy as np
import matplotlib.pyplot as plt

# %%
trace_dt=np.dtype([('stage1','i4'),('stage2','i4')])

# %%
traces_15_0=Data.fromfile('traces',trace_dt,'dsplib','two_stage_FIR71_15_0_TB',tool='vivado')
traces_18_3=Data.fromfile('traces',trace_dt,'dsplib','two_stage_FIR71_18_3_TB',tool='vivado')

# %%
(traces_15_0['stage1']-traces_18_3['stage1']).nonzero()
# Out:
# (array([], dtype=int64),)

# %%
# %matplotlib notebook
plt.plot(traces_15_0['stage1'],'r')
plt.plot(traces_18_3['stage1'],'b')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.plot(traces_15_0['stage2'],'r')
plt.plot(traces_18_3['stage2'],'b')
# Out:
# <img src="data:image/png;base64,..." width="640">
