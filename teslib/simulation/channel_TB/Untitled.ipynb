# %%
from tes.data import Data
import numpy as np
import matplotlib.pyplot as plt

# %%
trace_dt=np.dtype([('raw',np.int32),('filtered',np.int32),('slope',np.int32),('baseline',np.int32)])
traces=Data.fromfile('traces',trace_dt,'teslib','channel_TB','vivado')

# %%
# %matplotlib notebook
plt.plot(traces['filtered'][500:]/2)
# Out:
# <img src="data:image/png;base64,...">

# %%
stream_dt=np.dtype([('data',np.uint64),('last',np.int32)])
stream=Data.fromfile('stream',stream_dt,'teslib','channel_TB','vivado')

# %%
stream['last']
# Out:
# array([  10071,   10072,  -10073,   13053,   13054,  -13055,   17280,
#          17281,  -17282,   17545,   17546,  -17547,   18478,   18479,
#         -18480,   19034,   19035,  -19036,   20486,   20487,  -20488,
#          21083,   21084,  -21085,   21631,   21632,  -21633,   25117,
#          25118,  -25119,   37428,   37429,  -37430,   44029,   44030,
#         -44031,   58446,   58447,  -58448,   69367,   69368,  -69369,
#          71370,   71371,  -71372,   72104,   72105,  -72106,   79833,
#          79834,  -79835,   84224,   84225,  -84226,   85595,   85596,
#         -85597,   87344,   87345,  -87346,   90246,   90247,  -90248,
#          90684,   90685,  -90686,   97006,   97007,  -97008,   97745,
#          97746,  -97747,  100723,  100724, -100725,  100968,  100969,
#        -100970])
