# %%
import tes.simulation.data as sim
import numpy as np

# %%
bytestream=sim.Data.fromfile('bytestream',np.dtype([('data', np.uint8),('last',np.uint8)]),
                             'teslib','ethernet_framer_TB',)

# %%
len(bytestream['data'])
# Out:
# 32888

# %%
p=sim.PacketStream(bytestream)

# %%
p.packets
# Out:
# [ethertype:88B5 length:48 Payload:tick frame:0 protocol:0,
#  ethertype:88B5 length:152 Payload:peak frame:1 protocol:1,
#  ethertype:88B6 length:800 Payload:mca frame:2 protocol:0,
#  ethertype:88B6 length:800 Payload:mca frame:4 protocol:1,
#  ethertype:88B6 length:800 Payload:mca frame:6 protocol:2,
#  ethertype:88B5 length:48 Payload:tick frame:8 protocol:5,
#  ethertype:88B6 length:800 Payload:mca frame:9 protocol:3,
#  ethertype:88B6 length:800 Payload:mca frame:11 protocol:4,
#  ethertype:88B5 length:48 Payload:tick frame:13 protocol:8,
#  ethertype:88B6 length:800 Payload:mca frame:14 protocol:5,
#  ethertype:88B5 length:160 Payload:peak frame:16 protocol:10,
#  ethertype:88B5 length:48 Payload:tick frame:17 protocol:11,
#  ethertype:88B5 length:48 Payload:tick frame:18 protocol:12,
#  ethertype:88B5 length:160 Payload:peak frame:19 protocol:13,
#  ethertype:88B5 length:48 Payload:tick frame:20 protocol:14,
#  ethertype:88B5 length:48 Payload:tick frame:21 protocol:15,
# ...
